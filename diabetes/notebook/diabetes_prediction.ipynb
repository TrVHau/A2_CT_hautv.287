# %% [markdown]
# # DỰ ĐOÁN BỆNH TIỂU ĐƯỜNG (DIABETES PREDICTION)
#
# **Assignment 02 - Intelligent System Development**
#
# **Ngày:** 2026-09-03
#
# ---

# %% [markdown]
# ## 1. Định nghĩa bài toán (Problem Definition)
#
# Phần này sẽ mô tả:
# - Mục tiêu của ứng dụng: dự đoán khả năng mắc bệnh tiểu đường dựa trên các đặc điểm lâm sàng
# - Định nghĩa biến đầu vào X (đặc điểm bệnh nhân)
# - Định nghĩa biến mục tiêu y (lớp tiểu đường: 0 hoặc 1)
# - Loại bài toán: phân loại nhị phân (binary classification)

# %% [markdown]
# ## 2. Nguồn dữ liệu (Dataset Source)
#
# Phần này sẽ cung cấp:
# - Tên dataset từ Kaggle
# - URL của dataset
# - Số lượng quan sát (observations)
# - Số lượng thuộc tính (attributes)
# - Tên các đặc trưng (feature names)
# - Kiểu dữ liệu (data types)
# - Biến mục tiêu (target variable)
# - Mô tả một quan sát (description of one observation)

# %% [markdown]
# ## 3. Tải dữ liệu (Dataset Loading)
#
# Phần này sẽ thực hiện:
# - Import các thư viện cần thiết
# - Đọc file CSV vào DataFrame
# - Hiển thị 5 dòng đầu tiên
# - Xác nhận dữ liệu đã được tải thành công

# %% [markdown]
# ## 4. Khảo sát dữ liệu (Dataset Inspection)
#
# Phần này sẽ thực hiện:
# - df.shape - kích thước của DataFrame
# - df.head() - hiển thị mẫu dữ liệu
# - df.info() - thông tin về kiểu dữ liệu và giá trị non-null
# - df.describe() - thống kê mô tả các biến số
# - Xác định các cột số (numerical columns)
# - Xác định các cột phân loại (categorical columns)
# - Xác định cột mục tiêu (target column)

# %% [markdown]
# ## 5. Phân tích chất lượng dữ liệu (Data Quality Analysis)
#
# Phần này sẽ phân tích tổng quan về chất lượng dữ liệu:
# - Tổng số quan sát
# - Tổng số thuộc tính
# - Các vấn đề về chất lượng đã phát hiện
# - Đánh giá tổng thể về tình trạng dữ liệu

# %% [markdown]
# ## 6. Phân tích giá trị thiếu (Missing Value Analysis)
#
# Phần này sẽ:
# - Sử dụng df.isna().sum() để đếm giá trị thiếu
# - Tính phần trăm giá trị thiếu cho mỗi cột
# - Trực quan hóa giá trị thiếu (nếu có)
# - Giải thích ý nghĩa của việc có/không có giá trị thiếu

# %% [markdown]
# ## 7. Phân tích bản sao (Duplicate Analysis)
#
# Phần này sẽ:
# - Sử dụng df.duplicated().sum() để đếm số dòng trùng lặp
# - Hiển thị các dòng trùng lặp (nếu có)
# - Giải thích tại sao cần loại bỏ bản sao
# - Xóa các dòng trùng lặp và báo cáo số lượng dòng còn lại

# %% [markdown]
# ## 8. Phân tích giá trị không hợp lệ (Invalid Value Analysis)
#
# Phần này sẽ:
# - Kiểm tra giá trị nằm ngoài phạm vi hợp lý (ví dụ: tuổi âm, BMI không hợp lệ)
# - Kiểm tra các giá trị phân loại không nhất quán
# - Xác định các giá trị bất thường cần xử lý
# - Giải thích tại sao các giá trị này không hợp lệ

# %% [markdown]
# ## 9. Phân tích ngoại lệ (Outlier Analysis)
#
# Phần này sẽ:
# - Sử dụng boxplot để trực quan hóa outliers
# - Tính IQR (Interquartile Range) để phát hiện outliers
# - Phân tích xem outliers có phải là lỗi đo lường hay giá trị thực
# - Quyết định có loại bỏ outliers hay không (với giải thích)

# %% [markdown]
# ## 10. Phân tích dữ liệu khám phá (Exploratory Data Analysis)
#
# Phần này sẽ bao gồm:
# - **Phân phối biến mục tiêu (target distribution):** số lượng và tỷ lệ class 0 vs class 1
# - **Phân phối các đặc trưng quan trọng:** histogram cho age, bmi, glucose, HbA1c
# - **Mối quan hệ giữa đặc trưng và mục tiêu:** so sánh phân phối giữa nhóm có/không có tiểu đường
# - **Phân tích tương quan:** correlation matrix cho các biến số
# - Ít nhất 3 biểu đồ có ý nghĩa với đầy đủ: Observation, Interpretation, ML implication

# %% [markdown]
# ## 11. Các loại đặc trưng (Feature Types)
#
# Phần này sẽ phân loại các đặc trưng:
# - **Đặc trưng số liên tục (numerical continuous):** age, bmi, HbA1c_level, blood_glucose_level
# - **Đặc trưng nhị phân (binary):** hypertension, heart_disease
# - **Đặc trưng phân loại (categorical):** gender, smoking_history
# - **Biến mục tiêu (target):** diabetes (binary: 0/1)
# - Giải thích tại sao việc phân loại này quan trọng cho preprocessing

# %% [markdown]
# ## 12. Biểu diễn dữ liệu (Data Representation) ⭐
#
# **Phần trọng tâm - Kết nối với Lecture 02**
#
# Phần này sẽ minh họa chi tiết:
# 1. **Một dòng CSV gốc** (raw CSV record)
# 2. **DataFrame row tương ứng** (parsed data)
# 3. **Sau khi mã hóa phân loại:** gender → one-hot (3 features), smoking_history → one-hot (6 features)
# 4. **Sau khi chuẩn hóa:** scaling các biến số
# 5. **Vector đặc trưng xi ∈ ℝ^d** cho một bệnh nhân
# 6. **Ma trận đặc trưng X ∈ ℝ^(N×d)** cho toàn bộ dataset
# 7. **In ra shape thực tế:**
#    - X_train.shape
#    - X_test.shape
#    - Số chiều d thực tế sau mã hóa (expected: d=15)
# 8. **Kiểu dữ liệu (dtype)**
# 9. **Vector mục tiêu y ∈ {0,1}^N**
#
# **KHÔNG hardcode shape - phải derive từ dữ liệu thực tế!**

# %% [markdown]
# ## 13. Kỹ thuật đặc trưng (Feature Engineering)
#
# Phần này sẽ xem xét:
# - Có cần tạo đặc trưng tương tác không? (ví dụ: BMI × age)
# - Có cần biến đổi phi tuyến không? (log, sqrt, polynomial)
# - Có cần binning không?
# - **Quyết định:** Với diabetes dataset, chúng ta sẽ giữ nguyên các đặc trưng gốc để đảm bảo tính khả diễn giải

# %% [markdown]
# ## 14. Chia tập train/test (Train/Test Split)
#
# Phần này sẽ:
# - Tách X (features) và y (target)
# - Sử dụng train_test_split với:
#   - test_size=0.2 (80/20 split)
#   - random_state=42 (để tái tạo)
#   - **stratify=y** (quan trọng vì class imbalance 91.5%/8.5%)
# - In ra kích thước của X_train, X_test, y_train, y_test
# - Xác nhận phân phối class được giữ nguyên trong cả train và test
# - **Giải thích tại sao phải split TRƯỚC KHI fit preprocessing**

# %% [markdown]
# ## 15. Pipeline tiền xử lý (Preprocessing Pipeline)
#
# Phần này sẽ xây dựng sklearn Pipeline bao gồm:
# - **ColumnTransformer** để xử lý từng loại đặc trưng:
#   - Numerical features: StandardScaler
#   - Categorical features: OneHotEncoder
# - **FIT ONLY trên X_train** (tránh data leakage)
# - **TRANSFORM** cả X_train và X_test bằng fitted pipeline
# - In ra shape sau preprocessing
# - Giải thích tại sao cùng một preprocessing phải được dùng cho inference

# %% [markdown]
# ## 16. Mô hình cơ sở (Baseline Model)
#
# Phần này sẽ:
# - Train một mô hình đơn giản (Logistic Regression) làm baseline
# - Đánh giá hiệu suất trên tập train và test
# - Tính các metrics cơ bản: accuracy, precision, recall, F1
# - Đây là mốc để so sánh với các mô hình phức tạp hơn

# %% [markdown]
# ## 17. Huấn luyện mô hình (Model Training)
#
# Phần này sẽ train 5 mô hình:
# 1. **Logistic Regression** (baseline)
# 2. **Decision Tree Classifier**
# 3. **Random Forest Classifier**
# 4. **Support Vector Machine (SVM)**
# 5. **K-Nearest Neighbors (KNN)**
#
# Mỗi mô hình sẽ:
# - Sử dụng random_state=42
# - Xem xét class_weight='balanced' cho mô hình hỗ trợ (để xử lý imbalance)
# - Được train trên X_train_processed, y_train
# - Lưu lại để đánh giá

# %% [markdown]
# ## 18. So sánh mô hình (Model Comparison)
#
# Phần này sẽ tạo bảng so sánh:
#
# | Model | Accuracy | Precision | Recall | F1 | ROC-AUC |
# |-------|----------|-----------|--------|----|---------|
# | Logistic Regression | ... | ... | ... | ... | ... |
# | Decision Tree | ... | ... | ... | ... | ... |
# | Random Forest | ... | ... | ... | ... | ... |
# | SVM | ... | ... | ... | ... | ... |
# | KNN | ... | ... | ... | ... | ... |
#
# Với giải thích ý nghĩa của từng metric trong ngữ cảnh dự đoán tiểu đường.

# %% [markdown]
# ## 19. Đánh giá (Evaluation)
#
# Phần này sẽ đánh giá chi tiết các mô hình:
# - **Accuracy:** tỷ lệ dự đoán đúng tổng thể
# - **Precision:** trong số dự đoán có bệnh, bao nhiêu % thực sự có bệnh
# - **Recall:** trong số người thực sự có bệnh, phát hiện được bao nhiêu %
# - **F1-score:** trung bình điều hòa của precision và recall
# - **ROC-AUC:** khả năng phân biệt giữa hai class
# - **Confusion Matrix:** phân tích chi tiết TP, TN, FP, FN
#
# **Giải thích ý nghĩa trong y học:** Recall cao quan trọng hơn (không bỏ sót bệnh nhân)

# %% [markdown]
# ## 20. Phân tích lỗi (Error Analysis)
#
# Phần này sẽ phân tích:
# - **False Positives (FP):** dự đoán có bệnh nhưng thực tế không có
# - **False Negatives (FN):** dự đoán không bệnh nhưng thực tế có bệnh (nguy hiểm hơn!)
# - Xem xét đặc điểm của các trường hợp dự đoán sai
# - Có pattern nào trong các lỗi không?
# - Đề xuất cải thiện

# %% [markdown]
# ## 21. Lựa chọn mô hình (Model Selection)
#
# Phần này sẽ chọn mô hình tốt nhất dựa trên:
# - **Hiệu suất dự đoán:** metrics trên tập test
# - **Khả năng diễn giải:** mô hình có giải thích được không?
# - **Chi phí tính toán:** thời gian train và inference
# - **Tính ổn định (robustness)**
# - **Ràng buộc triển khai:** môi trường production
#
# **KHÔNG chỉ chọn accuracy cao nhất** - phải justify dựa trên ngữ cảnh ứng dụng y tế.

# %% [markdown]
# ## 22. Lưu trữ mô hình (Model Persistence)
#
# Phần này sẽ:
# - Tạo Pipeline hoàn chỉnh: Preprocessing + Model
# - Sử dụng joblib.dump() để lưu:
#   - `preprocessor.joblib` (ColumnTransformer đã fit)
#   - `model.joblib` (mô hình đã train)
#   - Hoặc `pipeline.joblib` (pipeline hoàn chỉnh)
# - Xác nhận file đã được lưu thành công
# - Giải thích tại sao phải lưu cả preprocessing và model

# %% [markdown]
# ## 23. Kiểm tra suy luận (Inference Test)
#
# Phần này sẽ kiểm tra pipeline đã lưu:
# 1. **Load pipeline từ disk** bằng joblib.load()
# 2. **Tạo một mẫu dữ liệu mới** (ví dụ: một bệnh nhân với các đặc điểm cụ thể)
# 3. **Thực hiện dự đoán** sử dụng loaded pipeline
# 4. **Hiển thị kết quả:**
#    - Class dự đoán (0 hoặc 1)
#    - Xác suất/confidence (nếu có)
#    - Giải thích ý nghĩa của dự đoán
# 5. **Xác nhận preprocessing được áp dụng tự động** (không cần fit lại)
#
# Đây là bước quan trọng chứng minh hệ thống có thể triển khai thực tế!

# %% [markdown]
# ---
#
# ## Kết luận
#
# Notebook này đã hoàn thành 23 bước theo đúng yêu cầu Appendix B:
# - Xây dựng pipeline học máy hoàn chỉnh từ dữ liệu thô đến mô hình triển khai
# - Minh họa chi tiết quá trình biểu diễn dữ liệu (Data Representation)
# - Đảm bảo không có data leakage
# - So sánh 5 mô hình và chọn mô hình phù hợp
# - Lưu trữ và kiểm tra khả năng inference
#
# **Hệ thống dự đoán tiểu đường đã sẵn sàng cho bước tiếp theo: Triển khai Web API.**
